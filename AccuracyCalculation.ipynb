# %% [markdown]
# <a href="https://colab.research.google.com/github/luana-martins/JNose-Validation/blob/main/AccuracyCalculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Configuração do Ambiente

# %%
#Importação das bibliotecas utilizadas
import pandas as pd
import numpy as np
 
#bibliotecas gráficas
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns;
 
#bibliotecas de métricas
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from warnings import filterwarnings
from sklearn.metrics import precision_recall_fscore_support

# %% [markdown]
# # 2. Dataset

# %%
#Importação do dataset para variável 'dados'
dataset = pd.read_csv('https://raw.githubusercontent.com/luana-martins/JNose-Validation/main/data.csv');
dataset.head()
# Out:
#   Group  #  Manual-AR  ...  Manual-MNT  JNose-MNT  tsDetect-MNT
# 0    G1  1       True  ...       False      False         False
# 1    G1  2       True  ...       False      False         False
# 2    G1  3       True  ...        True      False         False
# 3    G1  4       True  ...       False      False         False
# 4    G1  5       True  ...       False      False         False
#
# [5 rows x 56 columns]

# %% [markdown]
# # 3. JNOSE - Matriz de Confusão

# %%
# JNOSE

for i in dataset:
  for j in dataset:
    colunm1 = i.split('-')
    colunm2 = j.split('-')
    if colunm1[0] == 'Manual' and colunm2[0] == 'JNose' and colunm2[1] == colunm1[1]:
      esperado = dataset[colunm1[0]+"-"+colunm1[1]]  
      detectado = dataset[colunm2[0]+"-"+colunm2[1]]
      acuracia = (accuracy_score(esperado, detectado) * 100)
      
      print("A acurácia do " + colunm1[1] + " foi %.2f%%" % acuracia)
      print( classification_report(esperado, detectado))
    
      # Matriz de confusão
      pd.DataFrame(confusion_matrix(esperado, detectado),
                   index=['neg', 'pos'], columns=['pred_neg', 'pred_pos'])
# Out:
# A acurácia do AR foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        11
#         True       1.00      1.00      1.00        54
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do CTL foi 96.92%
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98        48
#         True       1.00      0.88      0.94        17
#
#     accuracy                           0.97        65
#    macro avg       0.98      0.94      0.96        65
# weighted avg       0.97      0.97      0.97        65
#
# A acurácia do CI foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        60
#         True       1.00      1.00      1.00         5
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do EmpT foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        60
#         True       1.00      1.00      1.00         5
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do ECT foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        59
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do GF foi 95.38%
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97        59
#         True       0.71      0.83      0.77         6
#
#     accuracy                           0.95        65
#    macro avg       0.85      0.90      0.87        65
# weighted avg       0.96      0.95      0.96        65
#
# A acurácia do MG foi 83.08%
#               precision    recall  f1-score   support
#
#        False       0.87      0.95      0.90        55
#         True       0.40      0.20      0.27        10
#
#     accuracy                           0.83        65
#    macro avg       0.63      0.57      0.59        65
# weighted avg       0.79      0.83      0.81        65
#
# A acurácia do PS foi 98.46%
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99        62
#         True       0.75      1.00      0.86         3
#
#     accuracy                           0.98        65
#    macro avg       0.88      0.99      0.92        65
# weighted avg       0.99      0.98      0.99        65
#
# A acurácia do RA foi 98.46%
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99        62
#         True       0.75      1.00      0.86         3
#
#     accuracy                           0.98        65
#    macro avg       0.88      0.99      0.92        65
# weighted avg       0.99      0.98      0.99        65
#
# A acurácia do SE foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        59
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do VT foi 80.00%
#               precision    recall  f1-score   support
#
#        False       0.98      0.80      0.88        60
#         True       0.25      0.80      0.38         5
#
#     accuracy                           0.80        65
#    macro avg       0.61      0.80      0.63        65
# weighted avg       0.92      0.80      0.84        65
#
# A acurácia do ST foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        62
#         True       1.00      1.00      1.00         3
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do ET foi 78.46%
#               precision    recall  f1-score   support
#
#        False       0.94      0.72      0.82        43
#         True       0.62      0.91      0.74        22
#
#     accuracy                           0.78        65
#    macro avg       0.78      0.82      0.78        65
# weighted avg       0.83      0.78      0.79        65
#
# A acurácia do LT foi 92.31%
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95        50
#         True       0.78      0.93      0.85        15
#
#     accuracy                           0.92        65
#    macro avg       0.88      0.93      0.90        65
# weighted avg       0.93      0.92      0.93        65
#
# A acurácia do DA foi 95.38%
#               precision    recall  f1-score   support
#
#        False       0.96      0.98      0.97        56
#         True       0.88      0.78      0.82         9
#
#     accuracy                           0.95        65
#    macro avg       0.92      0.88      0.90        65
# weighted avg       0.95      0.95      0.95        65
#
# A acurácia do UT foi 90.77%
#               precision    recall  f1-score   support
#
#        False       0.98      0.91      0.94        55
#         True       0.64      0.90      0.75        10
#
#     accuracy                           0.91        65
#    macro avg       0.81      0.90      0.85        65
# weighted avg       0.93      0.91      0.91        65
#
# A acurácia do RO foi 84.62%
#               precision    recall  f1-score   support
#
#        False       0.88      0.95      0.91        55
#         True       0.50      0.30      0.37        10
#
#     accuracy                           0.85        65
#    macro avg       0.69      0.62      0.64        65
# weighted avg       0.82      0.85      0.83        65
#
# A acurácia do MNT foi 90.77%
#               precision    recall  f1-score   support
#
#        False       0.88      1.00      0.93        43
#         True       1.00      0.73      0.84        22
#
#     accuracy                           0.91        65
#    macro avg       0.94      0.86      0.89        65
# weighted avg       0.92      0.91      0.90        65

# %% [markdown]
# # 4. TSDETECT

# %%
# TsDetect

for i in dataset:
  for j in dataset:
    colunm1 = i.split('-')
    colunm2 = j.split('-')
    if colunm1[0] == 'Manual' and colunm2[0] == 'tsDetect' and colunm2[1] == colunm1[1]:
      esperado = dataset[colunm1[0]+"-"+colunm1[1]]  
      detectado = dataset[colunm2[0]+"-"+colunm2[1]]
      acuracia = (accuracy_score(esperado, detectado) * 100)
      
      print("A acurácia do " + colunm1[1] + " foi %.2f%%" % acuracia)
      print( classification_report(esperado, detectado))
    
      # Matriz de confusão
      pd.DataFrame(confusion_matrix(esperado, detectado),
                   index=['neg', 'pos'], columns=['pred_neg', 'pred_pos'])
# Out:
# A acurácia do AR foi 75.38%
#               precision    recall  f1-score   support
#
#        False       0.41      1.00      0.58        11
#         True       1.00      0.70      0.83        54
#
#     accuracy                           0.75        65
#    macro avg       0.70      0.85      0.70        65
# weighted avg       0.90      0.75      0.78        65
#
# A acurácia do CTL foi 96.92%
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98        48
#         True       1.00      0.88      0.94        17
#
#     accuracy                           0.97        65
#    macro avg       0.98      0.94      0.96        65
# weighted avg       0.97      0.97      0.97        65
#
# A acurácia do CI foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        60
#         True       1.00      1.00      1.00         5
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do EmpT foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        60
#         True       1.00      1.00      1.00         5
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do ECT foi 46.15%
#               precision    recall  f1-score   support
#
#        False       1.00      0.41      0.58        59
#         True       0.15      1.00      0.26         6
#
#     accuracy                           0.46        65
#    macro avg       0.57      0.70      0.42        65
# weighted avg       0.92      0.46      0.55        65
#
# A acurácia do GF foi 95.38%
#               precision    recall  f1-score   support
#
#        False       0.98      0.97      0.97        59
#         True       0.71      0.83      0.77         6
#
#     accuracy                           0.95        65
#    macro avg       0.85      0.90      0.87        65
# weighted avg       0.96      0.95      0.96        65
#
# A acurácia do MG foi 83.08%
#               precision    recall  f1-score   support
#
#        False       0.87      0.95      0.90        55
#         True       0.40      0.20      0.27        10
#
#     accuracy                           0.83        65
#    macro avg       0.63      0.57      0.59        65
# weighted avg       0.79      0.83      0.81        65
#
# A acurácia do PS foi 98.46%
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99        62
#         True       0.75      1.00      0.86         3
#
#     accuracy                           0.98        65
#    macro avg       0.88      0.99      0.92        65
# weighted avg       0.99      0.98      0.99        65
#
# A acurácia do RA foi 98.46%
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99        62
#         True       0.75      1.00      0.86         3
#
#     accuracy                           0.98        65
#    macro avg       0.88      0.99      0.92        65
# weighted avg       0.99      0.98      0.99        65
#
# A acurácia do SE foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        59
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do VT foi 92.31%
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96        60
#         True       0.00      0.00      0.00         5
#
#     accuracy                           0.92        65
#    macro avg       0.46      0.50      0.48        65
# weighted avg       0.85      0.92      0.89        65
#
# A acurácia do ST foi 100.00%
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        62
#         True       1.00      1.00      1.00         3
#
#     accuracy                           1.00        65
#    macro avg       1.00      1.00      1.00        65
# weighted avg       1.00      1.00      1.00        65
#
# A acurácia do ET foi 69.23%
#               precision    recall  f1-score   support
#
#        False       0.93      0.58      0.71        43
#         True       0.53      0.91      0.67        22
#
#     accuracy                           0.69        65
#    macro avg       0.73      0.75      0.69        65
# weighted avg       0.79      0.69      0.70        65
#
# A acurácia do LT foi 92.31%
#               precision    recall  f1-score   support
#
#        False       0.98      0.92      0.95        50
#         True       0.78      0.93      0.85        15
#
#     accuracy                           0.92        65
#    macro avg       0.88      0.93      0.90        65
# weighted avg       0.93      0.92      0.93        65
#
# A acurácia do DA foi 93.85%
#               precision    recall  f1-score   support
#
#        False       0.96      0.96      0.96        56
#         True       0.78      0.78      0.78         9
#
#     accuracy                           0.94        65
#    macro avg       0.87      0.87      0.87        65
# weighted avg       0.94      0.94      0.94        65
#
# A acurácia do UT foi 90.77%
#               precision    recall  f1-score   support
#
#        False       0.98      0.91      0.94        55
#         True       0.64      0.90      0.75        10
#
#     accuracy                           0.91        65
#    macro avg       0.81      0.90      0.85        65
# weighted avg       0.93      0.91      0.91        65
#
# A acurácia do RO foi 84.62%
#               precision    recall  f1-score   support
#
#        False       0.88      0.95      0.91        55
#         True       0.50      0.30      0.37        10
#
#     accuracy                           0.85        65
#    macro avg       0.69      0.62      0.64        65
# weighted avg       0.82      0.85      0.83        65
#
# A acurácia do MNT foi 89.23%
#               precision    recall  f1-score   support
#
#        False       0.86      1.00      0.92        43
#         True       1.00      0.68      0.81        22
#
#     accuracy                           0.89        65
#    macro avg       0.93      0.84      0.87        65
# weighted avg       0.91      0.89      0.89        65
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
